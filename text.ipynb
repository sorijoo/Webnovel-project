# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import os
from konlpy.tag import Okt
from collections import Counter

# %%
base_path = "data/"
os.listdir(base_path)
# Out:
# ['novel_list_top_100_무협.csv',
#  'novel_list_top_100_라이트노벨.csv',
#  'novel_list_top_100_로맨스.csv',
#  'novel_list_top_100_미스터리.csv',
#  'novel_list_top_100_현판.csv',
#  'novel_list_top_100_BL.csv',
#  'novel_list_top_100_판타지.csv',
#  'novel_list_top_100_로판.csv']

# %%
# for i in os.listdir(base_path):
#     text = pd.read_csv(f"{i}")

# %%
muhyup = pd.read_csv("data/novel_list_top_100_무협.csv")
linovel = pd.read_csv("data/novel_list_top_100_라이트노벨.csv")
romance = pd.read_csv("data/novel_list_top_100_로맨스.csv")
mystery = pd.read_csv("data/novel_list_top_100_미스터리.csv")
hyunfan = pd.read_csv("data/novel_list_top_100_현판.csv")
bl = pd.read_csv("data/novel_list_top_100_BL.csv")
fantasy = pd.read_csv("data/novel_list_top_100_판타지.csv")
rofan = pd.read_csv("data/novel_list_top_100_로판.csv")

# %%
muhyup
# Out:
#                       제목                                                 요약
# 0              화산귀환 [독점]   대 화산파 13대 제자. 천하삼대검수(天下三代劍手)...
# 1            사상 최강의 무림맹원   [특기]#방화 #목젖뽑기 #독살 #심장터ᄄ...
# 2    절대 검감(絶對 劍感) [외전포함]   [제5회 대한민국 웹소설 공모대전 수상ᄌ...
# 3          일타강사 백사부 [독점]   혈교 최고의 무공교관, 시골 무관의 사부로...
# 4              광마회귀 [독점]   미친 사내가 미치기 전의 평범했던 시절ᄅ...
# ..                   ...                                                ...
# 96               중생지마교교주   *이 작품은 封七月 작가의 소설 拜見教主大人(2017)ᄋ...
# 97                    전왕   모든 것을 잃었다.모든 것의 끝을 보아...
# 98                  무인이곽   평범한 무인의 위대한 여정!“한번 개의 ...
# 99                 무신귀환록   『삼류회귀록』『천도쟁패』『칠룡칠마전』기ᄃ...
# 100            절세무혼 [독점]   - 이 작품은 洛城东의 소설 绝世武魂(2016)을 한ᄀ...
#
# [101 rows x 2 columns]

# %%
tmp = muhyup.apply(lambda x: str(x["제목"]) + str(x["요약"]), axis=1)

corpus = " ".join(tmp.tolist())

# %%
muhyup
# Out:
#                       제목                                                 요약
# 0              화산귀환 [독점]   대 화산파 13대 제자. 천하삼대검수(天下三代劍手)...
# 1            사상 최강의 무림맹원   [특기]#방화 #목젖뽑기 #독살 #심장터ᄄ...
# 2    절대 검감(絶對 劍感) [외전포함]   [제5회 대한민국 웹소설 공모대전 수상ᄌ...
# 3          일타강사 백사부 [독점]   혈교 최고의 무공교관, 시골 무관의 사부로...
# 4              광마회귀 [독점]   미친 사내가 미치기 전의 평범했던 시절ᄅ...
# ..                   ...                                                ...
# 96               중생지마교교주   *이 작품은 封七月 작가의 소설 拜見教主大人(2017)ᄋ...
# 97                    전왕   모든 것을 잃었다.모든 것의 끝을 보아...
# 98                  무인이곽   평범한 무인의 위대한 여정!“한번 개의 ...
# 99                 무신귀환록   『삼류회귀록』『천도쟁패』『칠룡칠마전』기ᄃ...
# 100            절세무혼 [독점]   - 이 작품은 洛城东의 소설 绝世武魂(2016)을 한ᄀ...
#
# [101 rows x 2 columns]

# %%
okt = Okt()
nouns = okt.nouns(corpus) 
words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외
c = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함
wc = WordCloud(font_path='System/Library/Fonts/JejuGothic.ttf', scale=2.0,background_color='white')
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.figure(figsize = (12, 10))
plt.axis('off')
plt.imshow(gen)

# %% [markdown]
# # 텍스트 추출

# %%
genre = fantasy

def make_wordcloud(genre):
    
    # text = pd.read_csv(f"data/novel_list_top_100_{장르}.csv")
    tmp = genre.apply(lambda x: str(x["제목"]) + str(x["요약"]), axis=1)
    corpus = " ".join(tmp.tolist())


    #okt = Okt()
    nouns = okt.nouns(corpus) 
    words = [n for n in nouns if len(n) > 1]
     # 단어의 길이가 1개인 것은 제외
    c = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함
    wc = WordCloud(font_path='System/Library/Fonts/JejuGothic.ttf', scale=2.0,background_color='white')
    gen = wc.generate_from_frequencies(c)
    plt.figure()
    plt.figure(figsize = (12, 10))
    plt.axis('off')
    
    return plt.imshow(gen)

# %%
make_wordcloud(genre)
